# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Sara Mathews Part 1-2

# %%
#reading the data
data = pd.read_csv('data.csv')
data.head()
# Out:
#    Close_ETF       oil      gold       JPM
# 0  97.349998  0.039242  0.004668  0.032258
# 1  97.750000  0.001953 -0.001366 -0.002948
# 2  99.160004 -0.031514 -0.007937  0.025724
# 3  99.650002  0.034552  0.014621  0.011819
# 4  99.260002  0.013619 -0.011419  0.000855

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
# Close_ETF    1000 non-null float64
# oil          1000 non-null float64
# gold         1000 non-null float64
# JPM          1000 non-null float64
# dtypes: float64(4)
# memory usage: 31.3 KB

# %% [markdown]
# ## Part 1
#
# ### The data includes four columns: the daily ETF return, the daily relative change in the price of crude oil, the daily relative change in the gold price and the daily return of the JP Morgan Chase & Co stock. The sample size is 1000.

# %%
data
# Out:
#       Close_ETF       oil      gold       JPM
# 0     97.349998  0.039242  0.004668  0.032258
# 1     97.750000  0.001953 -0.001366 -0.002948
# 2     99.160004 -0.031514 -0.007937  0.025724
# 3     99.650002  0.034552  0.014621  0.011819
# 4     99.260002  0.013619 -0.011419  0.000855
# 5     98.250000  0.003199 -0.005501 -0.038998
# 6     99.250000  0.011480 -0.027600  0.009479
# 7    100.300003  0.014187  0.008191  0.013498
# 8    100.610001 -0.023624 -0.004513  0.004632
# 9     99.559998 -0.024833  0.010201  0.000000
# 10   101.660004  0.016650  0.006732  0.036023
# 11   101.660004 -0.001927  0.009473  0.003894
# 12   101.570000 -0.025740 -0.012835 -0.028263
# 13   100.019997 -0.013871  0.010066 -0.017679
# 14    99.440002  0.025787 -0.012097  0.010160
# 15    98.419998 -0.013386 -0.012974 -0.027299
# 16    98.519997 -0.005625 -0.016749  0.013294
# 17    97.529999  0.053245  0.003032 -0.009038
# 18    98.800003 -0.084676 -0.010363  0.012062
# ...

# %% [markdown]
# ### Find below the sample mean and standard deviation for each random variable

# %%
data.describe()
# Out:
#          Close_ETF          oil         gold          JPM
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean    121.152960     0.001030     0.000663     0.000530
# std      12.569790     0.021093     0.011289     0.011017
# min      96.419998    -0.116533    -0.065805    -0.048217
# 25%     112.580002    -0.012461    -0.004816    -0.005538
# 50%     120.150002     0.001243     0.001030     0.000386
# 75%     128.687497     0.014278     0.007482     0.006966
# max     152.619995     0.087726     0.042199     0.057480

# %%
np.corrcoef(data.Close_ETF, data.oil)
# Out:
# array([[ 1.        , -0.00904484],
#        [-0.00904484,  1.        ]])

# %%
np.corrcoef(data.Close_ETF,data.gold)
# Out:
# array([[1.        , 0.02299557],
#        [0.02299557, 1.        ]])

# %%
np.corrcoef(data.Close_ETF,data.JPM)
# Out:
# array([[1.        , 0.03680706],
#        [0.03680706, 1.        ]])

# %%
np.corrcoef(data.oil,data.gold)
# Out:
# array([[1.        , 0.23565037],
#        [0.23565037, 1.        ]])

# %%
np.corrcoef(data.oil,data.JPM)
# Out:
# array([[ 1.        , -0.12084893],
#        [-0.12084893,  1.        ]])

# %%
np.corrcoef(data.gold,data.JPM)
# Out:
# array([[1.        , 0.10016984],
#        [0.10016984, 1.        ]])

# %% [markdown]
# ## Part 2
# ## Data description
# ### 1. Histograms

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['Close_ETF'].hist(bins = 25)
plt.title('Histogram for Close_ETF')
# Out:
# Text(0.5, 1.0, 'Histogram for Close_ETF')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['oil'].hist(bins = 200)
plt.title('Histogram for Oil')
# Out:
# Text(0.5, 1.0, 'Histogram for Oil')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['gold'].hist(bins = 200)
plt.title('Histogram for Gold')
# Out:
# Text(0.5, 1.0, 'Histogram for Gold')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['JPM'].hist(bins = 200)
plt.title('Histogram for JPM')
# Out:
# Text(0.5, 1.0, 'Histogram for JPM')

# %% [markdown]
# ### 2. Time series plot for each column

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['Close_ETF'].plot()
plt.title('Time Series for Close_ETF')
plt.xlabel('Day')
plt.ylabel('Closing Price')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['gold'].plot()
plt.title('Time Series for Gold')
plt.xlabel('Day')
plt.ylabel('Daily Change')
# Out:
# Text(0, 0.5, 'Daily Change')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['oil'].plot()
plt.title('Time Series for Oil')
plt.xlabel('Day')
plt.ylabel('Daily Change')
# Out:
# Text(0, 0.5, 'Daily Change')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['JPM'].plot()
plt.title('Time Series for JPM')
plt.xlabel('Day')
plt.ylabel('Daily Change')
# Out:
# Text(0, 0.5, 'Daily Change')

# %% [markdown]
# ### 3. Time series plot for all the four columns

# %%
data.plot(figsize = (15,10))

# %% [markdown]
# ### 4. Scatter plots presenting relationships between data

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
plt.scatter(data.Close_ETF,data.oil)
plt.title('Scatter Plot of Close_ETF versus Oil')
plt.xlabel('ETF Closing Price')
plt.ylabel('Oil Daily Change')
# Out:
# Text(0, 0.5, 'Oil Daily Change')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
plt.scatter(data.Close_ETF,data.gold)
plt.title('Scatter Plot of Close_ETF versus Gold')
plt.xlabel('ETF Closing Price')
plt.ylabel('Gold Daily Change')
# Out:
# Text(0, 0.5, 'Gold Daily Change')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
plt.scatter(data.Close_ETF,data.JPM)
plt.title('Scatter Plot of Close_ETF versus JPM')
plt.xlabel('ETF Closing Price')
plt.ylabel('JPM Daily Change')
# Out:
# Text(0, 0.5, 'JPM Daily Change')

# %% [markdown]
# # Robert Lando Part 3-4

# %%
import scipy.stats as stats

# %% [markdown]
# # Fitting ETF Data to a Cauchy and Normal Distribution

# %%
fit_parameters_cauchy_etf = stats.cauchy.fit(data['Close_ETF'])
fit_parameters_norm_etf = stats.norm.fit(data['Close_ETF'])

x = np.arange(0,200,1)
pdf_cauchy_etf = stats.cauchy.pdf(x,fit_parameters_cauchy_etf[0],fit_parameters_cauchy_etf[1])
pdf_norm_etf = stats.cauchy.pdf(x,fit_parameters_norm_etf[0],fit_parameters_norm_etf[1])

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_cauchy_etf,color = 'red')
plt.hist(data['Close_ETF'], bins = 25)
plt.title('ETF Closing Price Cauchy Fit')
plt.xlabel('Closing Price')
plt.ylabel('Count Frequency')
plt.show()

cauchy_test_etf = stats.kstest(data['Close_ETF'],"cauchy",fit_parameters_cauchy_etf)
norm_test_etf = stats.kstest(data['Close_ETF'],"norm",fit_parameters_norm_etf)

print('Cauchy Test Results:',cauchy_test_etf)
# Out:
# Cauchy Test Results: KstestResult(statistic=0.10149393348823577, pvalue=2.0211838498665748e-09)

# %% [markdown]
# The p-value is significantly less than .05, therefore we reject the null hypothesis that the data fits a Cauchy Distribution. Moreover, the plot clearly does not show any resemblance.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_norm_etf,color = 'red')
plt.hist(data['Close_ETF'],bins=25)
plt.title('ETF Closing Price Normal Fit')
plt.xlabel('Closing Price')
plt.ylabel('Count Frequency')
plt.show()

print('Normal Test Results:',norm_test_etf)
# Out:
# Normal Test Results: KstestResult(statistic=0.050248023432186595, pvalue=0.012378235790052549)

# %% [markdown]
# The p-value is significantly less than .05, therefore we reject the null hypothesis that the data fits a Normal Distribution. Moreover, the plot clearly does not show any resemblance.

# %% [markdown]
# # Fitting JPM Data to a Cauchy and Normal Distribution

# %%
fit_parameters_cauchy_jpm = stats.cauchy.fit(data['JPM'])
fit_parameters_norm_jpm = stats.norm.fit(data['JPM'])

x = np.arange(-.1,.1,.0005)
pdf_cauchy_jpm = stats.cauchy.pdf(x,fit_parameters_cauchy_jpm[0],fit_parameters_cauchy_jpm[1])
pdf_norm_jpm = stats.cauchy.pdf(x,fit_parameters_norm_jpm[0],fit_parameters_norm_jpm[1])

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_cauchy_jpm,color = 'red')
plt.hist(data['JPM'],bins=200)
plt.title('JPM Daily Change Cauchy Fit')
plt.xlabel('Daily Change')
plt.ylabel('Count Frequency')
plt.show()

cauchy_test_JPM = stats.kstest(data['JPM'],"cauchy",fit_parameters_cauchy_jpm)
norm_test_JPM = stats.kstest(data['JPM'],"norm",fit_parameters_norm_jpm)

print('Cauchy Test Results:',cauchy_test_JPM)
# Out:
# Cauchy Test Results: KstestResult(statistic=0.06087670598647191, pvalue=0.0011547253625532649)

# %% [markdown]
# The p-value is significantly less than the target value of .05, therefore we reject the null hypothesis that the data fits a Cauchy Distribution.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_norm_jpm,color = 'red')
plt.hist(data['JPM'],bins=200)
plt.title('JPM Daily Change Normal Fit')
plt.xlabel('Daily Change')
plt.ylabel('Count Frequency')
plt.show()
print('Normal Test Results:',norm_test_JPM)
# Out:
# Normal Test Results: KstestResult(statistic=0.046039810313210444, pvalue=0.0279329786031179)

# %% [markdown]
# The p-value is about half the target value of .05, therefore we reject the null hypothesis that the data fits a Normal Distribution. Although, the plot shows at least a faint resemblance.

# %% [markdown]
# # Fitting Oil Data to a Cauchy and Normal Distribution

# %%
#Fitting Oil Data to a Cauchy Distribution and a Normal Distribution

fit_parameters_cauchy_oil = stats.cauchy.fit(data['oil'])
fit_parameters_norm_oil = stats.norm.fit(data['oil'])

x = np.arange(-.125,.125,.0005)

pdf_cauchy_oil = stats.cauchy.pdf(x,fit_parameters_cauchy_oil[0],fit_parameters_cauchy_oil[1])
pdf_norm_oil = stats.norm.pdf(x,fit_parameters_norm_oil[0],fit_parameters_norm_oil[1])


fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_cauchy_oil,color = 'red')
plt.hist(data['oil'],bins=200)
plt.xlabel('Daily Change')
plt.ylabel('Count Frequency')
plt.title('Oil Daily Change Cauchy Fit')
plt.show()

cauchy_test_oil = stats.kstest(data['oil'],"cauchy",fit_parameters_cauchy_oil)
print('Cauchy Test Results:',cauchy_test_oil)
# Out:
# Cauchy Test Results: KstestResult(statistic=0.07063562956227883, pvalue=8.76931570747667e-05)

# %% [markdown]
# The p-value is significantly less than the target value of .05, therefore we reject the null hypothesis that the data fits a Cauchy Distribution.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_norm_oil,color = 'red')
plt.hist(data['oil'],bins=200)
plt.xlabel('Daily Change')
plt.ylabel('Count Frequency')
plt.title('Oil Daily Change Normal Fit')
plt.show()

norm_test_oil = stats.kstest(data['oil'],"norm",fit_parameters_norm_jpm)
print('Normal Test Results: ', norm_test_oil)
# Out:
# Normal Test Results:  KstestResult(statistic=0.14813380235645757, pvalue=1.2826262271410137e-19)

# %% [markdown]
# The p-value is significantly less than the target value of .05, therefore we reject the null hypothesis that the Oil data fits a Normal Distribution.

# %% [markdown]
# # Fitting Gold Data to a Cauchy and Normal Distribution

# %%
#Fitting Gold Data to a Cauchy Distribution and a Normal Distribution

fit_parameters_cauchy_gold = stats.cauchy.fit(data['gold'])
fit_parameters_norm_gold = stats.norm.fit(data['gold'])

x = np.arange(-.125,.125,.0005)

pdf_cauchy_gold = stats.cauchy.pdf(x,fit_parameters_cauchy_gold[0],fit_parameters_cauchy_gold[1])
pdf_norm_gold = stats.norm.pdf(x,fit_parameters_norm_gold[0],fit_parameters_norm_gold[1])

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_cauchy_gold,color = 'red')
plt.hist(data['oil'],bins=200)
plt.xlabel('Daily Change')
plt.ylabel('Count Frequency')
plt.title('Gold Daily Change Cauchy Fit')
plt.show()

cauchy_test_gold = stats.kstest(data['gold'],"cauchy",fit_parameters_cauchy_gold)
print('Cauchy Test Results:',cauchy_test_gold)
# Out:
# Cauchy Test Results: KstestResult(statistic=0.06469269497745544, pvalue=0.0004410903229246378)

# %% [markdown]
# The p-value is significantly less than the target value of .05, therefore we reject the null hypothesis that the Gold data fits a Cauchy Distribution.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(x,pdf_norm_gold,color = 'red')
plt.hist(data['gold'],bins=200)
plt.xlabel('Daily Change')
plt.ylabel('Count Frequency')
plt.title('Gold Daily Change Normal Fit')
plt.show()

norm_test_gold = stats.kstest(data['gold'],"norm",fit_parameters_norm_jpm)
print('Normal Test Results: ', norm_test_oil)
# Out:
# Normal Test Results:  KstestResult(statistic=0.14813380235645757, pvalue=1.2826262271410137e-19)

# %% [markdown]
# The p-value is significantly less than the target value of .05, therefore we reject the null hypothesis that the Gold data fits a Normal Distribution.

# %% [markdown]
# # Part 4

# %%
ETF_mean = data['Close_ETF'].mean()
ETF_std = data['Close_ETF'].std()
print('ETF mean =',ETF_mean,'\nETF std = ',ETF_std)
# Out:
# ETF mean = 121.1529600120001
# ETF std =  12.569790313110744

# %% [markdown]
# # I.
# We sequentially cut the ETF Data into 50 subsets of size 20 and calculate their respective means. Next, given the resulting distribution of the sequential subset means, we calculate its mean and standard deviation.

# %%
data['group_1'] = pd.cut(data['Close_ETF'],bins = 50, labels = False)

group_means = []
for i in range(50):
    mu = data[data['group_1'] == i]['Close_ETF'].mean()
    group_means.append(mu)

# %%
subsets = pd.DataFrame({'Mean':group_means})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
subsets['Mean'].hist(bins = 50)
plt.xlabel('Subset Mean')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of ETF Subset (size 20) Means')
plt.show()

# %% [markdown]
# The histogram is not normal and skewed. It does not appear to follow any well known distribution.

# %%
mean_of_subset_means_20 = subsets['Mean'].mean()
std_of_subset_means_20 = subsets['Mean'].std()
std_over_root_50 = ETF_std/np.sqrt(50) 

print('Mean of subset means =',mean_of_subsets_20,'\n','std of subset means =',std_of_subsets_20)
print('\n')
print('ETF Pupulation mean =',ETF_mean) 
print('ETF Population std =',ETF_std)
print('\n')
print('n=50, ','(ETF Population std)/root(n) = ',std_over_root_50)
# Out:
# Mean of subset means = 124.5163890051454
#  std of subset means = 16.354348306008223
#
#
# ETF Pupulation mean = 121.1529600120001
# ETF Population std = 12.569790313110744
#
#
# n=50,  (ETF Population std)/root(n) =  1.7776367936987165

# %% [markdown]
# The average of the sequential subset means is larger than the ETF population mean by about 3.
#
# The standard deviation of the sequential subset means is much larger than the ETF population standard deviation over root(n), where n = 50.
#
# The results above are not consistent with the Central Limit Theorem because the sample of subsets was made sequentially, not randomly. Moreover, the number of subsets created is nowhere near large enough at only 50.

# %% [markdown]
# # II
# We sequentially cut the ETF Data into 10 subsets of size 100 and calculate their respective means. Next, given the resulting distribution of the sequential subset means, we calculate its mean and standard deviation.

# %%
data['group_2'] = pd.cut(data['Close_ETF'],bins = 10, labels = False)

group_means_2 = []
for i in range(10):
    mu_2 = data[data['group_1'] == i]['Close_ETF'].mean()
    group_means_2.append(mu_2)

# %%
subsets_2 = pd.DataFrame({'Mean':group_means_2})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
subsets_2['Mean'].hist()
plt.xlabel('Random Sample Mean')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of ETF Subset (size 100) Means')
plt.show()

# %% [markdown]
# According to the histogram, the distribution is not normal. It appears to be a uniform distribution.

# %%
mean_of_subset_means_100 = subsets_2['Mean'].mean()
std_of_subset_means_100 = subsets_2['Mean'].std()
std_over_root_10 = ETF_std/np.sqrt(10) 

print('Mean of subset means =',mean_of_subsets_100,'\n','std of subset means =',std_of_subsets_100)
print('\n')
print('ETF Population mean =',ETF_mean) 
print('ETF Population std =',ETF_std)
print('\n')
print('n=10, ','(ETF Population std)/root(n) = ',std_over_root_10)
# Out:
# Mean of subset means = 102.09438896756801
#  std of subset means = 3.3942945873301147
#
#
# ETF Population mean = 121.1529600120001
# ETF Population std = 12.569790313110744
#
#
# n=10,  (ETF Population std)/root(n) =  3.9749167100151

# %% [markdown]
# The average of the sequential subset means is much smaller than the ETF population mean.
#
# The standard deviation of the subset means is slightly smaller than the sample standard deviation over root(n), where n = 10.
#
# The results above are not consistent with the Central Limit Theorem because the subsets were made sequentially, not randomly. Moreover, the number of subsets created is nowhere near large enough at only 10.

# %% [markdown]
# # III
# We generate 50 random samples of size 20 (with replacement) from the population ETF Data and calculate their respective means.
# Next, given the resulting distribution of the random sample means, we calculate its mean and standard deviation.

# %%
group_means = []

i = 1

while (i <= 50):
    
    a = np.random.choice(data.Close_ETF, size = 20, replace = True).mean()
    group_means.append(a)
    i+=1
    continue

# %%
df_group_means = pd.DataFrame({'Mean':group_means})
df_group_means.head(50)
# Out:
#           Mean
# 0   120.676499
# 1   122.908999
# 2   122.658499
# 3   120.120000
# 4   116.400002
# 5   123.922000
# 6   119.220000
# 7   124.053000
# 8   120.406500
# 9   119.437999
# 10  121.957499
# 11  123.705500
# 12  120.285000
# 13  119.847999
# 14  121.721999
# 15  117.708999
# 16  120.240000
# 17  119.586000
# 18  122.900500
# 19  124.684501
# 20  123.128500
# 21  117.931501
# 22  122.234501
# 23  124.276500
# 24  119.229500
# 25  122.135501
# 26  126.044500
# 27  127.260000
# 28  127.107499
# 29  123.618501
# 30  124.080501
# 31  121.561500
# 32  118.105000
# 33  117.914500
# 34  117.740500
# 35  123.594000
# 36  120.131000
# 37  121.055500
# 38  114.342499
# 39  116.113499
# 40  121.600500
# 41  118.988999
# 42  121.988501
# 43  116.866500
# 44  125.287000
# 45  119.272500
# 46  122.324000
# 47  117.080000
# 48  119.234501
# 49  121.977001

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df_group_means['Mean'].hist(bins = 10)
plt.xlabel('Random Sample Mean')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of n=50 Random Sample Means From Population ETF Data')
plt.show()

# %% [markdown]
# According to the histogram, it's definitely not a normal distribution. The number of samples drawn is likely too small for any well known distribution to be come out.

# %%
mean_of_random_sample_means = df_group_means['Mean'].mean()
std_of_random_sample_means = df_group_means['Mean'].std()
std_over_root_50 = ETF_std/np.sqrt(50)

print('Mean of random sample means =',mean_of_random_samples,'\n','std of random sample means =',std_of_random_samples)
print('\n')
print('ETF Population Mean =',ETF_mean) 
print('ETF Population std =',ETF_std)
print('\n')
print('n=50, ','(Etf Population std)/root(n) = ',std_over_root_50)
# Out:
# Mean of random sample means = 120.867790061
#  std of random sample means = 3.192494878229785
#
#
# ETF Population Mean = 121.1529600120001
# ETF Population std = 12.569790313110744
#
#
# n=50,  (Etf Population std)/root(n) =  1.7776367936987165

# %% [markdown]
# The mean of the random sample means is very close to the population mean.
#
# The standard deviation of random sample means is larger than the sample standard deviation over root(n), where n = 50.
#
# The number of random samples drawn is too small to be consistent with the Central Limit Theorem, however it is encouraging that the average of the random sample means was closely comparable to the population mean.

# %% [markdown]
# # IV
# We generate 10 random samples of size 100 (with replacement) from the population ETF Data and calculate their respective means.
# Next, given the resulting distribution of the random sample means, we calculate its mean and standard deviation.

# %%
group_means_2 = []

i = 1

while (i <= 10):
    
    a = np.random.choice(data.Close_ETF, size = 100, replace = True).mean()
    group_means_2.append(a)
    i+=1
    continue

# %%
df_group_means_2 = pd.DataFrame({'Mean':group_means_2})
df_group_means_2.head(10)
# Out:
#        Mean
# 0  119.5155
# 1  120.7478
# 2  120.6379
# 3  117.5825
# 4  118.8418
# 5  119.2592
# 6  120.9067
# 7  119.3898
# 8  121.9752
# 9  121.4562

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df_group_means_2['Mean'].hist(bins = 10)
plt.xlabel('Subset Mean')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of n=10 Random Sample Means From Population ETF Data')
plt.show()

# %% [markdown]
# According to the histogram, the distribution is not normal. It follows no well known distribution.

# %%
mean_of_random_sample_means_2 = df_group_means_2['Mean'].mean()
std_of_random_sample_means_2 = df_group_means_2['Mean'].std()
std_over_root_10 = ETF_std/np.sqrt(10)

print('Mean of random sample means =',mean_of_random_sample_means_2,'\n','std of random sample means =',std_of_random_sample_means_2)
print('\n')
print('ETF Population Mean =',ETF_mean) 
print('ETF Population std =',ETF_std)
print('\n')
print('n=10, ','(Etf Population std)/root(n) = ',std_over_root_10)
# Out:
# Mean of random sample means = 120.03125989100002
#  std of random sample means = 1.3392364687469143
#
#
# ETF Population Mean = 121.1529600120001
# ETF Population std = 12.569790313110744
#
#
# n=10,  (Etf Population std)/root(n) =  3.9749167100151

# %% [markdown]
# The average of the random sample means is very close to the population mean.
#
# The standard deviation of random sample means is significantly smaller than the sample standard deviation over root(n), where n = 10.
#
# This is still not consistent with the Central Limit Theorem. We likely need n (number of groups we take from the population with replacement) to be as large as possible. How large each element (group) of the sample is does not matter as much. When we average the means of each group, we should still get a value closely comparable to the population mean. We may be able to get closer to a Normal Distribution if we take n=100 random samples of size 10.
#
# A related question to consider is if the number of values drawn overall is allowed to exceed 1000. If so, we would have more freedom to make n as large as necessary in order to see if a Normal distribution arises.

# %% [markdown]
# # Zhengyang Zhang Part 7-9

# %%
import seaborn as sns
import math
from sklearn import linear_model
import statsmodels.api as sm

# %% [markdown]
# # Part 7

# %% [markdown]
# ** H0: Mu_G == Mu_O **
#
# ** Ha: Mu_G != Mu_O **

# %%
stats.ttest_ind(data.gold,data.oil)
# Out:
# Ttest_indResult(statistic=-0.485366608948659, pvalue=0.6274695292874639)

# %% [markdown]
# Since P is 0.627, which is larger than 0.05. Therefore we will not reject the null hypothesis at this case.

# %% [markdown]
# ** H0: Mu_G - Mu_O == 0**
#
# ** Ha: Mu_G - Mu_O != 0 **

# %%
mean_diff = data.oil - data.gold
stats.ttest_1samp(mean_diff,0)
# Out:
# Ttest_1sampResult(statistic=0.5413309223847729, pvalue=0.5884002046805893)

# %% [markdown]
# Since P is 0.588, which is larger than 0.05. Therefore we will not reject the null hypothesis at this case.

# %% [markdown]
# ** H0: sigma_G == sigma_O **
#
# ** Ha: sigma_G != sigma_O **

# %%
std_gold = stats.sem(data.gold)
std_oil = stats.sem(data.oil)

# %%
F = (std_gold)**2 / (std_oil)**2
stats.f.cdf(F, 999, 999)
# Out:
# 3.942300247719849e-82

# %% [markdown]
# Since P value is way less 0.05, so we would reject the null hypothesis at this case.

# %% [markdown]
# # Part 8

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(data.gold,data.Close_ETF)
plt.title('Scatter Plot for Close_ETF and gold')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Close_ETF and gold')

# %% [markdown]
# There doesn't seem to have a linear relationship between the two variable.

# %%
np.corrcoef(data.gold,data.Close_ETF)
# Out:
# array([[1.        , 0.02299557],
#        [0.02299557, 1.        ]])

# %% [markdown]
# The coefficient seems very small, it's only 0.022, this is an indication that there is a weak linear relationship between the two columns.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.regplot(x = data.gold,y = data.Close_ETF)
plot = plt.title('Scatter Plot for Close_ETF and Gold with best fit line')

# %%
np.polyfit(x = data.gold,y = data.Close_ETF,deg=1)
# Out:
# array([ 25.60438932, 121.1359885 ])

# %% [markdown]
# The regression line is Close_ETF = 25.60438932*gold + 121.1359885

# %%
X = data['gold']
Y = data['Close_ETF']
X = sm.add_constant(X)
# Out:
# C:\Users\robla\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
ols = sm.OLS(Y,X).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Close_ETF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5280
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.468
# Time:                        20:29:30   Log-Likelihood:                -3949.5
# No. Observations:                1000   AIC:                             7903.
# Df Residuals:                     998   BIC:                             7913.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        121.1360      0.398    304.155      0.000     120.354     121.918
# ...

# %%
t = 25.6044/35.236
d_f = 1000-2
t
# Out:
# 0.7266545578385742

# %%
p = 1 - stats.t.cdf(t,df=d_f)
p*2
# Out:
# 0.46760799530738817

# %% [markdown]
# The p-value is 0.46. At the significance level 0.01, the test is significant. Therefore we will not reject the null hypothesis beta1 = 0 at significance level 0.01. That means there is no linear relationship at signifiance level 0.01.

# %%
def linear_eqt(x):
    return(25.60438932*x + 121.1359885)

# %%
Close_ETF = data.Close_ETF.tolist()
pred_ETF = []
for i in range(1000):
    pred_ETF.append(linear_eqt(data.gold[i]))

# %%
corr_matrix = np.corrcoef(Close_ETF, pred_ETF)
corr = corr_matrix[0,1]
R_sq = corr**2
print(R_sq)
# Out:
# 0.0005287962431227516

# %% [markdown]
# No, it's not a good model, the R^2 is extremely small that means there is a really weak linear relationship between Close_ETF and gold.

# %% [markdown]
# I assumed there is a weak relationship between Close_ETF and gold, and the result is as expected as my assumption, the linear relationship is really weak.

# %%
# CI for mean daily ETF 
stats.norm.interval(alpha=0.99, loc=linear_eqt(np.mean(data.gold)), scale= stats.sem(pred_ETF))
# Out:
# (121.12941552280834, 121.17650450338938)

# %%
# CI for individual daily ETF 
stats.norm.interval(alpha = 0.99,loc = linear_eqt(0.005127), scale = stats.sem(pred_ETF))
# Out:
# (121.24371771375311, 121.29080669433415)

# %% [markdown]
# # Part 9

# %%
X = data[['gold','oil']]
Y = data['Close_ETF']

# %%
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  121.14272529623004
# Coefficients:
#  [29.62259192 -9.12610011]

# %%
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)
# Out:
# C:\Users\robla\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Close_ETF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3743
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.688
# Time:                        21:15:03   Log-Likelihood:                -3949.4
# No. Observations:                1000   AIC:                             7905.
# Df Residuals:                     997   BIC:                             7919.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        121.1427      0.399    303.856      0.000     120.360     121.925
# ...

# %% [markdown]
# Here the adjusted R^2 is -0.001, which means I have choosen a model that its fit is worse than a horizontal line. In other word, this model is worse than the original model with only gold and Close_ETF in terms of the fitting accuracy.

# %% [markdown]
# # Part 10

# %% [markdown]
# # Oil regression and residuals + residual Normal Q-Q Plot

# %%
import statsmodels.api as sm

# %%
X = data[['Close_ETF','gold']]
Y = data['oil']

# %%
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
Oil_predictions = model.predict(X)

# %%
#print(Oil_predictions)

# %%
Oil_res = []

# %%
for i in range(0,len(Oil_predictions)):
    Oil_res.append(Y[i] - Oil_predictions[i])
Oil_res = np.array(Oil_res)

# %%
Oil_pred_mean = Gold_predictions.mean()
Oil_res_mean = Oil_res.mean()
print('Mean of Oil Residuals =',Oil_res_mean)
Oil_center = [Oil_pred_mean,Oil_res_mean]
# Out:
# Mean of Oil Residuals = 1.4446777107934848e-17

# %% [markdown]
# Which is extremely small, fitting our assumption that the mean of the residuals should be zero.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(Oil_predictions,Oil_res)
plt.scatter(Oil_center[0],Oil_center[1],color = 'r')
plt.hlines(0,-.04,.03,linewidth = .5, colors = 'black')
plt.vlines(0,-.15,.1,linewidth = .5, colors = 'black')
plt.xlim(-.040,.03)
plt.ylim(-.15,.1)
plt.title('Oil Residuals')
plt.xlabel('Predicted Oil Daily Change Values')
plt.ylabel('Residuals')
plt.show()

# %%
print('Center Point:',Oil_center)
# Out:
# Center Point: [0.0006628360820000082, 1.4446777107934848e-17]

# %% [markdown]
# Additionally there are no obvious curvatures or trends indicating non constant variance. The residuals seem to all be clustered approximately around the point (.0007,0).

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(Oil_res)
plt.xlim(0,1000)
plt.title('Oil Residual Time Series')
plt.xlabel('Day')
plt.ylabel('Oil Residual Value')
plt.show()

# %% [markdown]
# Oil residual time series shows no time dependence, and somewhat randomly oscilates about 0. So we can say the Oil residuals fit the independence assumption.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.acorr(Oil_res)
plt.title('Oil Residual Autocorrelation Plot')
plt.xlabel('Lags')
plt.ylabel('Autocorrelation Function')
plt.show()

# %%
fig = sm.qqplot(Oil_res,dist = 'norm',line='s')
fig.set_size_inches(11.7, 8.27)
plt.title('Oil Residual Normal Q-Q Plot')
plt.xlabel('Normal Quantiles')
plt.ylabel('Ordered Oil Residuals')
plt.show()

# %% [markdown]
# The Gold Residual Normal Q-Q Plot hovers closely around the standardized line from about the Normal -2 quantile to the Normal 2 quantile. Outside of that interval the plot deviates quite a bit from the line which is expected at the outermost quantiles. We can say the Oil residual data is not normal. This is likely because the Oil data itself is also not normally distributed based on the ks-test done in part 3.

# %% [markdown]
# # Gold regression and residuals + residual Normal Q-Q Plot

# %%
X = data[['Close_ETF','oil']]
Y = data['gold']

# %%
#print(Y)

# %%
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
Gold_predictions = model.predict(X)

# %%
Gold_res = []

# %%
for i in range(0,len(Gold_predictions)):
    Gold_res.append(Y[i] - Gold_predictions[i])
Gold_res = np.array(Gold_res)

# %%
#print(Gold_predictions)

# %%
Gold_pred_mean = Gold_predictions.mean()
Gold_res_mean = Gold_res.mean()
print('Mean of Gold Residuals =',Gold_res_mean)
Gold_center = [Gold_pred_mean,Gold_res_mean]
# Out:
# Mean of Gold Residuals = -8.257283745649601e-18

# %% [markdown]
# Which is extremely small, fitting our assumption that the mean of the residuals should be zero.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(Gold_predictions,Gold_res)
plt.scatter(Gold_center[0],Gold_center[1],c='r')
plt.hlines(0,-.03,.02,linewidth = .5, colors = 'black')
plt.vlines(0,-.07,.05,linewidth = .5, colors = 'black')
plt.xlim(-.020,.015)
plt.ylim(-.07,.05)
plt.title('Gold Residuals')
plt.xlabel('Predicted Gold Values')
plt.ylabel('Residuals')
plt.show()

# %%
print('Center Point:',Gold_center)
# Out:
# Center Point: [0.0006628360820000082, -8.257283745649601e-18]

# %% [markdown]
# Additionally there are no obvious curvatures or trends indicating non constant variance. The residuals seem to all be clustered approximately around the point (.0007,0).

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(Gold_res)
plt.xlim(0,1000)
plt.title('Gold Residual Time Series')
plt.xlabel('Day')
plt.ylabel('Gold Residual Value')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.acorr(Gold_res)
plt.title('Gold Residual Autocorrelation Plot')
plt.xlabel('Lags')
plt.ylabel('Autocorrelation Function')
plt.show()

# %% [markdown]
# Gold residual time series shows no time dependence, and somewhat randomly oscilates about 0. So we can say the Gold residuals fit the independence assumption.

# %%
fig = sm.qqplot(Gold_res,dist = 'norm',line='s')
fig.set_size_inches(11.7, 8.27)
plt.title('Gold Residual Normal Q-Q Plot')
plt.xlabel('Normal Quantiles')
plt.ylabel('Ordered Gold Residuals')
plt.show()

# %% [markdown]
# The Gold Residual Normal Q-Q Plot deviates from the standardized line a lot around the -2 Normal quantile. The plot hovers close around the standardized line from about the -1 Normal quantile to the Normal 2 quantile. It is probably safe to assume that the Gold residual data is not normal. This is likely because the Gold Data itself is also not normally distributed based on the ks-test done in part 3.

# %% [markdown]
# # ETF regression and residuals + residual Normal Q-Q Plot

# %%
X = data[['gold','oil']]
Y = data['Close_ETF']

# %%
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
ETF_predictions = model.predict(X)

# %%
ETF_res = []

# %%
for i in range(0,len(Gold_predictions)):
    ETF_res.append(Y[i] - ETF_predictions[i])
ETF_res = np.array(ETF_res)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(ETF_predictions,ETF_res)
plt.hlines(0,119,123,colors = 'black',linewidth = 1)
#plt.vlines(121,-30,40,colors = 'black',linewidth = 1)
plt.xlim(119,123)
#plt.ylim(-30,40)
plt.title('ETF Residuals')
plt.xlabel('Predicted ETF Values')
plt.ylabel('Residuals')
plt.show()

# %%
ETF_res_mean = ETF_res.mean()
print('Mean of ETF Residuals =',ETF_res_mean)
# Out:
# Mean of ETF Residuals = -3.0013325158506633e-14

# %% [markdown]
# Which is again extremely small, fitting our assumption that the mean of the residuals should be zero.

# %% [markdown]
# Variance is not increasing or decreasing with the predicted ETF values, indicating constant variance.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.plot(ETF_res)
plt.xlim(0,1000)
plt.title('ETF Residual Time Series')
plt.xlabel('Day')
plt.ylabel('ETF Residual Value')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.acorr(ETF_res)
plt.title('ETF Residual Autocorrelation Plot')
plt.xlabel('Lags')
plt.ylabel('Autocorrelation Function')
plt.show()

# %% [markdown]
# ETF residuals show a strong time dependence. Meaning, the residuals seem to be correlated. Therefore the ETF residuals are not independent, violating the assumption that they should be independent.

# %%
fig = sm.qqplot(ETF_res,dist = 'norm',line='s')
fig.set_size_inches(11.7, 8.27)
plt.title('ETF Residual Normal Q-Q Plot')
plt.xlabel('Normal Quantiles')
plt.ylabel('Ordered ETF Residuals')
plt.show()

# %% [markdown]
# The ETF Residual Normal Q-Q Plot deviates from the standardized line quite a bit outside the (-1,1) Normal quantile range. Therefore the residual data is not normally distributed. This is likely because the ETF Data itself is also not normally distributed based on the ks-test done in part 3.

# %% [markdown]
# In conclusion, the residuals from our ETF, Oil, and Gold multiple regression fits are consistent with the assumptions of constant variance, mean zero, and independence. However they do not fit the assumption that they are normally distributed. Consequently, our chosen model must be revisited.

# %%
fig = sm.qqplot(Y,dist = 'norm',line='s')
fig.set_size_inches(11.7, 8.27)
plt.title('ETF Data Normal Q-Q Plot')
plt.xlabel('Normal Quantiles')
plt.ylabel('Ordered ETF Quantiles')
plt.show()

# %%
#print(Oil_predictions)

# %%
#print(ETF_predictions)

# %%
#print(Gold_predictions)
